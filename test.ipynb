# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 폰트 경로 및 등록
font_path = "./eisenhower/fonts/Maplestory Light.ttf"
fm.fontManager.addfont(font_path)
font_prop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = font_prop.get_name()
plt.rcParams['axes.unicode_minus'] = False

# rcParams는 무시하고 FontProperties를 직접 써야 함
plt.figure(figsize=(8, 6))
plt.title("한글 테스트")
plt.plot([1, 2, 3], [1, 4, 9])
plt.xlabel("x축")
plt.ylabel("y축")
plt.show()

# %%
position = [
    ((3, 6), {"xmin": 0.5, "xmax": 1.0}),
    ((3, 6), {"xmin": 0.0, "xmax": 0.5}),
    ((0, 3), {"xmin": 0.5, "xmax": 1.0}),
    ((0, 3), {"xmin": 0.0, "xmax": 0.5}),
]
quadrant_labels = [
    ((5.5, 5.7), *position[0], "긴급 & 중요", '#FFB3BA'),
    ((0.7, 5.7), *position[1], "중요하지만 덜 긴급", '#FFDFBA'),
    ((5.3, 0.3), *position[2], "긴급하지만 덜 중요", '#BAFFC9'),
    ((0.7, 0.3), *position[3], "덜 중요 & 덜 긴급", '#BAE1FF'),
]

print(quadrant_labels)
# Out:
# [((5.5, 5.7), (3, 6), {'xmin': 0.5, 'xmax': 1.0}, '긴급 & 중요', '#FFB3BA'), ((0.7, 5.7), (3, 6), {'xmin': 0.0, 'xmax': 0.5}, '중요하지만 덜 긴급', '#FFDFBA'), ((5.3, 0.3), (0, 3), {'xmin': 0.5, 'xmax': 1.0}, '긴급하지만 덜 중요', '#BAFFC9'), ((0.7, 0.3), (0, 3), {'xmin': 0.0, 'xmax': 0.5}, '덜 중요 & 덜 긴급', '#BAE1FF')]
